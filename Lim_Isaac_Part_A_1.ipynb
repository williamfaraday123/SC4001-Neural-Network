# %% [markdown]
# <a href="https://colab.research.google.com/github/williamfaraday123/SC4001-Neural-Network/blob/main/Lim_Isaac_Part_A_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question A1 (15 marks)

# %% [markdown]
# #### Design a feedforward deep neural network (DNN) which consists of **three** hidden layers of 128 neurons each with ReLU activation function, and an output layer with sigmoid activation function. Apply dropout of probability **0.3** to each of the hidden layers.

# %%
# !wget https://raw.githubusercontent.com/williamfaraday123/SC4001-Neural-Network/refs/heads/main/common_utils.py -O common_utils.py
# Out:
# --2026-03-04 03:40:37--  https://raw.githubusercontent.com/williamfaraday123/SC4001-Neural-Network/refs/heads/main/common_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3724 (3.6K) [text/plain]
# Saving to: ‘common_utils.py’
#
# common_utils.py     100%[===================>]   3.64K  --.-KB/s    in 0s
#
# 2026-03-04 03:40:38 (37.0 MB/s) - ‘common_utils.py’ saved [3724/3724]

# %%
import tqdm
import time
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch import optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from scipy.io import wavfile as wav

from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix

from common_utils import set_seed, EarlyStopper

# setting seed
set_seed()

# %% [markdown]
# 1.Define the model class.

# %%
class MLP(nn.Module):

    def __init__(self, input_dim):
        super().__init__()
        self.mlp_stack = nn.Sequential(
            # YOUR CODE HERE
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    # YOUR CODE HERE
    def forward(self, x):
        return self.mlp_stack(x)

# %% [markdown]
# #### Divide the dataset into a 75:25 ratio for training and testing. Use **appropriate** scaling of input features. We solely assume that there are only two datasets here: training & test.

# %% [markdown]
# 2.Split the dataset and do preprocessing.

# %%
from common_utils import split_dataset, preprocess_dataset


def preprocess(df):
    # YOUR CODE HERE
    # Extract labels from 'filename'. Assuming filename contains 'positive' or 'negative'
    # Or if the filename itself is the label, encode it.
    # Adjust the lambda function below based on how the CSV represents labels.
    df['label'] = df['filename'].apply(lambda x: 'positive' if 'pos' in x.lower() else 'negative')

    X_train, y_train, X_test, y_test = split_dataset(
        df,
        columns_to_drop=['filename', 'label'],
        test_size=0.25,
        random_state=42
    )
    # Scaling features
    X_train, X_test = preprocess_dataset(X_train, X_test)

    # Convert to PyTorch Tensors
    X_train_scaled = torch.tensor(X_train, dtype=torch.float32)
    y_train_scaled = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
    X_test_scaled = torch.tensor(X_test, dtype=torch.float32)
    y_test_scaled = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)

    return X_train_scaled, y_train, X_test_scaled, y_test

df = pd.read_csv('https://raw.githubusercontent.com/williamfaraday123/SC4001-Neural-Network/refs/heads/main/simplified.csv')

X_train_scaled, y_train, X_test_scaled, y_test = preprocess(df)

# %%
df['label'].value_counts()
# Out:
# label
# 1    6202
# 0    5855
# Name: count, dtype: int64

# %% [markdown]
# #### Use the training dataset to train the model for 200 epochs. Use a mini-batch gradient descent with **‘Adam’** optimizer with learning rate of **0.0005**, weight decay of **0.0005** and **batch size = 64**. Implement early stopping with patience of **5**.

# %% [markdown]
# 3.Define a Pytorch Dataset and Dataloaders.

# %%
class CustomDataset(Dataset):
    # YOUR CODE HERE
    def __init__(self, X, y):
        # Convert numpy arrays to PyTorch tensors
        self.X = torch.tensor(X, dtype=torch.float32)
        # Ensure y is a 2D tensor (column vector) for BCELoss
        self.y = torch.tensor(y, dtype=torch.float32).unsqueeze(1)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

def initialise_loaders(X_train_scaled, y_train, X_test_scaled, y_test):
    # YOUR CODE HERE
    # Create instances of the CustomDataset
    train_dataset = CustomDataset(X_train_scaled, y_train)
    test_dataset = CustomDataset(X_test_scaled, y_test)

    # Initialize DataLoaders
    # Note: Training loader uses shuffle=True for better gradient descent
    train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
    test_dataloader = DataLoader(test_dataset, batch_size=64, shuffle=False)

    return train_dataloader, test_dataloader

train_dataloader, test_dataloader = initialise_loaders(X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# /tmp/ipykernel_304/3291384078.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.X = torch.tensor(X, dtype=torch.float32)

# %% [markdown]
# 4.Next, define the model, optimizer and loss function.

# %%
# YOUR CODE HERE
input_dim = X_train_scaled.shape[1]
model = MLP(input_dim)
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=0.0005)
loss_fn = nn.BCELoss()

# %% [markdown]
# 5.Train model for 200 epochs. Record down train and test accuracies. Implement early stopping.

# %%
# YOUR CODE HERE
epochs = 200
stopper = EarlyStopper(patience=5)

history = {'train_loss': [], 'test_loss': [], 'train_acc': [], 'test_acc': []}

for epoch in range(epochs):
    # --- TRAINING PHASE ---
    model.train()
    train_losses = []
    correct_train = 0
    total_train = 0

    for batch_X, batch_y in train_dataloader:
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = loss_fn(outputs, batch_y)
        loss.backward()
        optimizer.step()

        train_losses.append(loss.item())
        preds = (outputs > 0.5).float()
        correct_train += (preds == batch_y).sum().item()
        total_train += batch_y.size(0)

    # --- EVALUATION PHASE (Using test_dataloader) ---
    model.eval()
    test_losses = []
    correct_test = 0
    total_test = 0

    with torch.no_grad():
        for batch_X, batch_y in test_dataloader:
            outputs = model(batch_X)
            loss = loss_fn(outputs, batch_y)

            test_losses.append(loss.item())
            preds = (outputs > 0.5).float()
            correct_test += (preds == batch_y).sum().item()
            total_test += batch_y.size(0)

    # Calculate Epoch Metrics
    avg_train_loss = np.mean(train_losses)
    avg_train_acc = correct_train / total_train
    avg_test_loss = np.mean(test_losses)
    avg_test_acc = correct_test / total_test

    # Store in history
    history['train_loss'].append(avg_train_loss)
    history['test_loss'].append(avg_test_loss)
    history['train_acc'].append(avg_train_acc)
    history['test_acc'].append(avg_test_acc)

    print(f"Epoch {epoch+1}/{epochs} | Train Loss: {avg_train_loss:.4f} | Test Loss: {avg_test_loss:.4f} | Test Acc: {avg_test_acc:.4f}")

    # Early Stopping Logic (based on averaged test loss)
    if stopper.early_stop(avg_test_loss):
        print(f"Early stopping triggered at epoch {epoch+1}")
        break
# Out:
# Epoch 1/200 | Train Loss: 0.6794 | Test Loss: 0.6674 | Test Acc: 0.5907
# Epoch 2/200 | Train Loss: 0.6675 | Test Loss: 0.6573 | Test Acc: 0.6156
# Epoch 3/200 | Train Loss: 0.6584 | Test Loss: 0.6518 | Test Acc: 0.6212
# Epoch 4/200 | Train Loss: 0.6459 | Test Loss: 0.6382 | Test Acc: 0.6425
# Epoch 5/200 | Train Loss: 0.6403 | Test Loss: 0.6361 | Test Acc: 0.6425
# Epoch 6/200 | Train Loss: 0.6294 | Test Loss: 0.6271 | Test Acc: 0.6494
# Epoch 7/200 | Train Loss: 0.6204 | Test Loss: 0.6167 | Test Acc: 0.6584
# Epoch 8/200 | Train Loss: 0.6051 | Test Loss: 0.6109 | Test Acc: 0.6743
# Epoch 9/200 | Train Loss: 0.6000 | Test Loss: 0.6003 | Test Acc: 0.6786
# Epoch 10/200 | Train Loss: 0.5931 | Test Loss: 0.6003 | Test Acc: 0.6756
# Epoch 11/200 | Train Loss: 0.5781 | Test Loss: 0.5927 | Test Acc: 0.6776
# Epoch 12/200 | Train Loss: 0.5724 | Test Loss: 0.5872 | Test Acc: 0.6892
# Epoch 13/200 | Train Loss: 0.5642 | Test Loss: 0.5771 | Test Acc: 0.6972
# Epoch 14/200 | Train Loss: 0.5542 | Test Loss: 0.5731 | Test Acc: 0.7061
# Epoch 15/200 | Train Loss: 0.5492 | Test Loss: 0.5718 | Test Acc: 0.7045
# Epoch 16/200 | Train Loss: 0.5330 | Test Loss: 0.5648 | Test Acc: 0.7068
# Epoch 17/200 | Train Loss: 0.5238 | Test Loss: 0.5632 | Test Acc: 0.7108
# Epoch 18/200 | Train Loss: 0.5274 | Test Loss: 0.5582 | Test Acc: 0.7104
# Epoch 19/200 | Train Loss: 0.5171 | Test Loss: 0.5517 | Test Acc: 0.7201
# Epoch 20/200 | Train Loss: 0.5142 | Test Loss: 0.5477 | Test Acc: 0.7237
# Epoch 21/200 | Train Loss: 0.5043 | Test Loss: 0.5433 | Test Acc: 0.7207
# Epoch 22/200 | Train Loss: 0.5002 | Test Loss: 0.5397 | Test Acc: 0.7234
# Epoch 23/200 | Train Loss: 0.4848 | Test Loss: 0.5368 | Test Acc: 0.7274
# Epoch 24/200 | Train Loss: 0.4807 | Test Loss: 0.5375 | Test Acc: 0.7287
# Epoch 25/200 | Train Loss: 0.4783 | Test Loss: 0.5354 | Test Acc: 0.7231
# Epoch 26/200 | Train Loss: 0.4726 | Test Loss: 0.5382 | Test Acc: 0.7217
# Epoch 27/200 | Train Loss: 0.4710 | Test Loss: 0.5259 | Test Acc: 0.7310
# Epoch 28/200 | Train Loss: 0.4599 | Test Loss: 0.5268 | Test Acc: 0.7347
# Epoch 29/200 | Train Loss: 0.4552 | Test Loss: 0.5247 | Test Acc: 0.7363
# Epoch 30/200 | Train Loss: 0.4478 | Test Loss: 0.5284 | Test Acc: 0.7383
# Epoch 31/200 | Train Loss: 0.4428 | Test Loss: 0.5111 | Test Acc: 0.7486
# Epoch 32/200 | Train Loss: 0.4419 | Test Loss: 0.5233 | Test Acc: 0.7436
# Epoch 33/200 | Train Loss: 0.4390 | Test Loss: 0.5242 | Test Acc: 0.7373
# Epoch 34/200 | Train Loss: 0.4270 | Test Loss: 0.5094 | Test Acc: 0.7486
# Epoch 35/200 | Train Loss: 0.4245 | Test Loss: 0.5104 | Test Acc: 0.7466
# Epoch 36/200 | Train Loss: 0.4227 | Test Loss: 0.5023 | Test Acc: 0.7589
# Epoch 37/200 | Train Loss: 0.4165 | Test Loss: 0.5097 | Test Acc: 0.7539
# Epoch 38/200 | Train Loss: 0.4218 | Test Loss: 0.5034 | Test Acc: 0.7499
# Epoch 39/200 | Train Loss: 0.4117 | Test Loss: 0.5124 | Test Acc: 0.7512
# Epoch 40/200 | Train Loss: 0.4032 | Test Loss: 0.5062 | Test Acc: 0.7499
# Epoch 41/200 | Train Loss: 0.3949 | Test Loss: 0.5001 | Test Acc: 0.7566
# Epoch 42/200 | Train Loss: 0.4076 | Test Loss: 0.5038 | Test Acc: 0.7615
# Epoch 43/200 | Train Loss: 0.3990 | Test Loss: 0.4995 | Test Acc: 0.7566
# Epoch 44/200 | Train Loss: 0.4007 | Test Loss: 0.4948 | Test Acc: 0.7658
# Epoch 45/200 | Train Loss: 0.3913 | Test Loss: 0.5066 | Test Acc: 0.7476
# Epoch 46/200 | Train Loss: 0.3888 | Test Loss: 0.5029 | Test Acc: 0.7572
# Epoch 47/200 | Train Loss: 0.3803 | Test Loss: 0.4972 | Test Acc: 0.7632
# Epoch 48/200 | Train Loss: 0.3849 | Test Loss: 0.4978 | Test Acc: 0.7629
# Epoch 49/200 | Train Loss: 0.3822 | Test Loss: 0.5051 | Test Acc: 0.7566
# Early stopping triggered at epoch 49

# %% [markdown]
# #### Plot train and test accuracies and losses on training and test data against training epochs and comment on the line plots.

# %%
# YOUR CODE HERE
plt.figure(figsize=(12, 5))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(history['train_loss'], label='Train Loss')
plt.plot(history['test_loss'], label='Test Loss')
plt.title('Loss vs Epochs')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history['train_acc'], label='Train Acc')
plt.plot(history['test_acc'], label='Test Acc')
plt.title('Accuracy vs Epochs')
plt.legend()

plt.show()

# %% [markdown]
# 6.Comment on line plots.

# %%
# YOUR CODE HERE
answer = "Both train loss and test loss decrease, but they diverge more and more as number of epochs increases. Both train and test accuracy increase but they diverge as the number of epochs increases. The model is learning, but with increasing overfitting.\nAs the number of epochs increases beyond 40, the test loss and test accuracy plateau but the train loss continues to decrease. This means the model has reached its maximum generalisation capacity, and the optimal time for early stopping is at 40 epochs."
print(answer)
# Out:
# Both train loss and test loss decrease, but they diverge more and more as number of epochs increases. Both train and test accuracy increase but they diverge as the number of epochs increases. The model is learning, but with increasing overfitting.
# As the number of epochs increases beyond 40, the test loss and test accuracy plateau but the train loss continues to decrease. This means the model has reached its maximum generalisation capacity, and the optimal time for early stopping is at 40 epochs.
